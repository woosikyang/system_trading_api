# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://apis.data.go.kr/1230000/BidPublicInfoService04/getBidPblancListInfoCnstwk01?serviceKey=ZjZO8Y%2F%2FCLz4iBGEImRuxc%2B1FTJpN7RZxKhWNzgK8uJT4YehzUH9TyPApAKp8t4VrPczvlEwHtIgAEPJYCECvA%3D%3D&numOfRows=10&pageNo=1&inqryDiv=1&inqryBgnDt=202303070000&inqryEndDt=202305092359&type=json'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')
soup.prettify()
# Out:
# '{"response": {\n  "header": {\n    "resultCode": "00",\n    "resultMsg": "정상"\n  },\n  "body": {\n    "items": [\n      {\n        "bidNtceNo": "20220723068",\n        "bidNtceOrd": "01",\n        "reNtceYn": "N",\n        "rgstTyNm": "조달청 또는 나라장터 자체 공고건",\n        "ntceKindNm": "취소",\n        "intrbidYn": "N",\n        "bidNtceDt": "2023-03-21 16:04:08",\n        "refNo": "제주특별자치도교육청 공고 제2022-312호",\n        "bidNtceNm": "가파초 마라분교 (구)관사 수리 및 건물 철거 전기공사",\n        "ntceInsttCd": "9290000",\n        "ntceInsttNm": "제주특별자치도교육청",\n        "dminsttCd": "9290000",\n        "dminsttNm": "제주특별자치도교육청",\n        "bidMethdNm": "전자입찰",\n        "cntrctCnclsMthdNm": "수의(소액)-견적입찰(2인 이상 견적 제출)",\n        "ntceInsttOfclNm": "허은정",\n        "ntceInsttOfclTelNo": "064-710-0734",\n        "ntceInsttOfclEmailAdrs": "heun39@korea.kr",\n        "exctvNm": "허은정",\n        "bidQlfctRgstDt": "2022-07-25 18:00:00",\n        "cmmnSpldmdAgrmntRcptdocMethd": "공고서참조",\n        "cmmnSpldmdAgrmntClseDt": "",\n   
# ...

# %%
soup = BeautifulSoup(response, 'html.parser')
type(soup)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-d82475e87ed1> in <module>
# ----> 1 soup = BeautifulSoup(response, 'html.parser')
#       2 type(soup)
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     285         if hasattr(markup, 'read'):        # It's a file-type object.
#     286             markup = markup.read()
# --> 287         elif len(markup) <= 256 and (
#     288                 (isinstance(markup, bytes) and not b'<' in markup)
#     289                 or (isinstance(markup, str) and not '<' in markup)
#
# TypeError: object of type 'Response' has no len()

# %%
soup2 = soup.body
for child in soup2.children : 
    print(child)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-b950434881b1> in <module>
#       1 soup2 = soup.body
# ----> 2 for child in soup2.children :
#       3     print(child)
#
# AttributeError: 'NoneType' object has no attribute 'children'

# %%
soup.find('response')
